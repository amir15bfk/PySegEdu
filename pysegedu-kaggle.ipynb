# %% [markdown]
# <a href="https://www.kaggle.com/code/mohamedamirbenbachir/notebook68bcde972f"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" height=22.5></a>

# %% [markdown]
# # Clone The Repo
# if you are working with your fork change the repo link

# %%
# !git clone https://github.com/amir15bfk/PySegEdu.git
# Out:
# Cloning into 'PySegEdu'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 165 (delta 84), reused 123 (delta 42), pack-reused 0
# Receiving objects: 100% (165/165), 556.93 KiB | 19.89 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %% [markdown]
# # Install Requirements

# %%
# !cd PySegEdu && pip install -r requirements.txt
# !apt install rar

# %% [markdown]
# # Update
#
# if you want to configue your project in your local machine :
# - fork the project on github (https://github.com/amir15bfk/PySegEdu)
# - clone it to your pc
# - edit and push
# - clone your project to this colab instance insted of the original repo
# - after any change you push it
# - pull it using this cell

# %%
# !cd PySegEdu && git pull

# %% [markdown]
# # Check Your Config

# %%
# !cat PySegEdu/main.py

# %% [markdown]
# # Download Needed Data

# %%
# !python PySegEdu/utils/download.py

# %% [markdown]
# # RUN

# %%
# !python PySegEdu/main.py

# %% [markdown]
# # Rename The Last Save

# %%
# !mv /kaggle/working/Trained_models/FCBFormer_B_352 100ep_last.pt /kaggle/working/Trained_models/FCBFormer_B_352 100ep_last2.pt

# %% [markdown]
# # Download The Model From Kaggle

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink('Trained_models/FCBFormer_B_352 100ep_best.pt')
